# %% [markdown]
# # code-book rules for the "default ruleset for Java, by r2c"
#
# There are 28 rules in this ruleset. In the notebook, you'll find
# parallel implementations of each of the rules for `code-book`. This is
# to help me get an idea of what our high level API should look like, what
# kinds of operations we need to support, and where we might be able to
# "do better" than SemGrep. This also serves as a nice comparison for
# performance (eventually, will need to set SemGrep up on the same data).

# %%
# !gandiva-build.sh
# Out:
# /arrow/arrow-cpp-build /app/applications/jupyter-extension/nteract_on_jupyter/notebooks
# -- Building using CMake version: 3.20.0
# -- Arrow version: 4.0.0 (full: '4.0.0-SNAPSHOT')
# -- Arrow SO version: 400 (full: 400.0.0)
# -- clang-tidy not found
# -- clang-format not found
# -- Could NOT find ClangTools (missing: CLANG_FORMAT_BIN CLANG_TIDY_BIN)
# -- infer not found
# fatal: not a git repository: /arrow/../../.git/modules/query/arrow
# -- Found Python3: /usr/local/bin/python3.9 (found version "3.9.4") found components: Interpreter
# -- Found cpplint executable at /arrow/cpp/build-support/cpplint.py
# -- System processor: x86_64
# -- Arrow build warning level: CHECKIN
# Using ld linker
# Configured for DEBUG build (set with cmake -DCMAKE_BUILD_TYPE={release,debug,...})
# -- Build Type: DEBUG
# -- Using BUNDLED approach to find dependencies
# -- ARROW_ABSL_BUILD_VERSION: 0f3bb466b868b523cf1dc9b2aaaed65c77b28862
# -- ARROW_AWSSDK_BUILD_VERSION: 1.8.133
# -- ARROW_AWS_CHECKSUMS_BUILD_VERSION: v0.1.10
# -- ARROW_AWS_C_COMMON_BUILD_VERSION: v0.4.59
# -- ARROW_AWS_C_EVENT_STREAM_BUILD_VERSION: v0.1.5
# -- ARROW_BOOST_BUILD_VERSION: 1.75.0
# -- ARROW_BROTLI_BUILD_VERSION: v1.0.9
# -- ARROW_BZIP2_BUILD_VERSION: 1.0.8
# -- ARROW_CARES_BUILD_VERSION: 1.17.1
# -- ARROW_GBENCHMARK_BUILD_VERSION: v1.5.2
# -- ARROW_GFLAGS_BUILD_VERSION: v2.2.2
# -- ARROW_GLOG_BUILD_VERSION: v0.4.0
# -- ARROW_GRPC_BUILD_VERSION: v1.35.0
# -- ARROW_GTEST_BUILD_VERSION: 1.10.0
# -- ARROW_JEMALLOC_BUILD_VERSION: 5.2.1
# -- ARROW_LZ4_BUILD_VERSION: v1.9.3
# -- ARROW_MIMALLOC_BUILD_VERSION: v1.6.4
# -- ARROW_ORC_BUILD_VERSION: 1.6.6
# -- ARROW_PROTOBUF_BUILD_VERSION: v3.14.0
# -- ARROW_RAPIDJSON_BUILD_VERSION: 1a803826f1197b5e30703afe4b9c0e7dd48074f5
# -- ARROW_RE2_BUILD_VERSION: 2021-02-02
# -- ARROW_SNAPPY_BUILD_VERSION: 1.1.8
# -- ARROW_THRIFT_BUILD_VERSION: 0.13.0
# -- ARROW_THRIFT_BUILD_MD5_CHECKSUM: 38a27d391a2b03214b444cb13d5664f1
# -- ARROW_UTF8PROC_BUILD_VERSION: v2.6.1
# -- ARROW_XSIMD_BUILD_VERSION: e916f3ab1bc513328b627df702226a1d1e2ae3a9
# -- ARROW_ZLIB_BUILD_VERSION: 1.2.11
# -- ARROW_ZSTD_BUILD_VERSION: v1.4.8
# -- Boost include dir: /arrow/arrow-cpp-build/boost_ep-prefix/src/boost_ep
# -- Boost libraries: boost_system_static;boost_filesystem_static
# -- Building snappy from source
# -- Building brotli from source
# -- Building without OpenSSL support. Minimum OpenSSL version 1.0.2 required.
# Building Apache Thrift from source
# Building Protocol Buffers from source
# -- Found protoc: /arrow/arrow-cpp-build/protobuf_ep-install/bin/protoc
# -- Found libprotoc: /arrow/arrow-cpp-build/protobuf_ep-install/lib/libprotoc.a
# -- Found libprotobuf: /arrow/arrow-cpp-build/protobuf_ep-install/lib/libprotobuf.a
# -- Found protobuf headers: /arrow/arrow-cpp-build/protobuf_ep-install/include
# -- Building (vendored) jemalloc from source
# -- Building RapidJSON from source
# -- Building xsimd from source
# -- Building ZLIB from source
# -- Building lz4 from source
# -- Building zstd from source
# -- Building RE2 from source
# -- Building BZip2 from source
# -- Building utf8proc from source
# -- Found hdfs.h at: /arrow/cpp/thirdparty/hadoop/include/hdfs.h
# -- All bundled static libraries: Snappy::snappy;Brotli::brotlicommon;Brotli::brotlienc;Brotli::brotlidec;thrift::thrift;arrow::protobuf::libprotobuf;jemalloc::jemalloc;ZLIB::ZLIB;LZ4::lz4;zstd::libzstd;re2::re2;BZip2::BZip2;utf8proc::utf8proc
# -- CMAKE_C_FLAGS:  -ggdb -O0  -Wall -Wno-conversion -Wno-deprecated-declarations -Wno-sign-conversion -Wno-unused-variable -Werror -fno-semantic-interposition -msse4.2
# -- CMAKE_CXX_FLAGS:  -Wno-noexcept-type  -fdiagnostics-color=always -ggdb -O0  -Wall -Wno-conversion -Wno-deprecated-declarations -Wno-sign-conversion -Wno-unused-variable -Werror -fno-semantic-interposition -msse4.2
# -- Creating bundled static library target arrow_bundled_dependencies at /arrow/arrow-cpp-build/debug/libarrow_bundled_dependencies.a
# -- Found Python3: /usr/local/bin/python3.9 (found version "3.9.4") found components: Interpreter Development.Module NumPy
# -- Found Python3Alt: /usr/local/bin/python3.9
# -- Using LLVMConfig.cmake in: /usr/lib/llvm-11/cmake
# -- Found llvm-link /usr/lib/llvm-11/bin/llvm-link
# -- Found clang /usr/lib/llvm-11/bin/clang-11
# -- ---------------------------------------------------------------------
# -- Arrow version:                                 4.0.0-SNAPSHOT
# --
# -- Build configuration summary:
# --   Generator: Unix Makefiles
# --   Build type: DEBUG
# --   Source directory: /arrow/cpp
# --   Install prefix: /arrow/dist
# --
# -- Compile and link options:
# --
# --   ARROW_CXXFLAGS="" [default=""]
# --       Compiler flags to append when compiling Arrow
# --   ARROW_BUILD_STATIC=ON [default=ON]
# --       Build static libraries
# --   ARROW_BUILD_SHARED=ON [default=ON]
# --       Build shared libraries
# --   ARROW_PACKAGE_KIND="" [default=""]
# --       Arbitrary string that identifies the kind of package
# --       (for informational purposes)
# --   ARROW_GIT_ID="" [default=""]
# --       The Arrow git commit id (if any)
# --   ARROW_GIT_DESCRIPTION="" [default=""]
# --       The Arrow git commit description (if any)
# --   ARROW_NO_DEPRECATED_API=OFF [default=OFF]
# --       Exclude deprecated APIs from build
# --   ARROW_USE_CCACHE=ON [default=ON]
# --       Use ccache when compiling (if available)
# --   ARROW_USE_LD_GOLD=OFF [default=OFF]
# --       Use ld.gold for linking on Linux (if available)
# --   ARROW_USE_PRECOMPILED_HEADERS=OFF [default=OFF]
# --       Use precompiled headers when compiling
# --   ARROW_SIMD_LEVEL=SSE4_2 [default=NONE|SSE4_2|AVX2|AVX512]
# --       Compile-time SIMD optimization level
# --   ARROW_RUNTIME_SIMD_LEVEL=MAX [default=NONE|SSE4_2|AVX2|AVX512|MAX]
# --       Max runtime SIMD optimization level
# --   ARROW_ARMV8_ARCH=armv8-a [default=armv8-a|armv8-a+crc+crypto]
# --       Arm64 arch and extensions
# --   ARROW_ALTIVEC=ON [default=ON]
# --       Build with Altivec if compiler has support
# --   ARROW_RPATH_ORIGIN=OFF [default=OFF]
# --       Build Arrow libraries with RATH set to $ORIGIN
# --   ARROW_INSTALL_NAME_RPATH=ON [default=ON]
# --       Build Arrow libraries with install_name set to @rpath
# --   ARROW_GGDB_DEBUG=ON [default=ON]
# --       Pass -ggdb flag to debug builds
# --
# -- Test and benchmark options:
# --
# --   ARROW_BUILD_EXAMPLES=OFF [default=OFF]
# --       Build the Arrow examples
# --   ARROW_BUILD_TESTS=OFF [default=OFF]
# --       Build the Arrow googletest unit tests
# --   ARROW_ENABLE_TIMING_TESTS=ON [default=ON]
# --       Enable timing-sensitive tests
# --   ARROW_BUILD_INTEGRATION=OFF [default=OFF]
# --       Build the Arrow integration test executables
# --   ARROW_BUILD_BENCHMARKS=OFF [default=OFF]
# --       Build the Arrow micro benchmarks
# --   ARROW_BUILD_BENCHMARKS_REFERENCE=OFF [default=OFF]
# --       Build the Arrow micro reference benchmarks
# --   ARROW_TEST_LINKAGE=shared [default=shared|static]
# --       Linkage of Arrow libraries with unit tests executables.
# --   ARROW_FUZZING=OFF [default=OFF]
# --       Build Arrow Fuzzing executables
# --   ARROW_LARGE_MEMORY_TESTS=OFF [default=OFF]
# --       Enable unit tests which use large memory
# --
# -- Lint options:
# --
# --   ARROW_ONLY_LINT=OFF [default=OFF]
# --       Only define the lint and check-format targets
# --   ARROW_VERBOSE_LINT=OFF [default=OFF]
# --       If off, 'quiet' flags will be passed to linting tools
# --   ARROW_GENERATE_COVERAGE=OFF [default=OFF]
# --       Build with C++ code coverage enabled
# --
# -- Checks options:
# --
# --   ARROW_TEST_MEMCHECK=OFF [default=OFF]
# --       Run the test suite using valgrind --tool=memcheck
# --   ARROW_USE_ASAN=OFF [default=OFF]
# --       Enable Address Sanitizer checks
# --   ARROW_USE_TSAN=OFF [default=OFF]
# --       Enable Thread Sanitizer checks
# --   ARROW_USE_UBSAN=OFF [default=OFF]
# --       Enable Undefined Behavior sanitizer checks
# --
# -- Project component options:
# --
# --   ARROW_BUILD_UTILITIES=OFF [default=OFF]
# --       Build Arrow commandline utilities
# --   ARROW_COMPUTE=ON [default=OFF]
# --       Build the Arrow Compute Modules
# --   ARROW_CSV=ON [default=OFF]
# --       Build the Arrow CSV Parser Module
# --   ARROW_CUDA=OFF [default=OFF]
# --       Build the Arrow CUDA extensions (requires CUDA toolkit)
# --   ARROW_DATASET=ON [default=OFF]
# --       Build the Arrow Dataset Modules
# --   ARROW_FILESYSTEM=ON [default=OFF]
# --       Build the Arrow Filesystem Layer
# --   ARROW_FLIGHT=OFF [default=OFF]
# --       Build the Arrow Flight RPC System (requires GRPC, Protocol Buffers)
# --   ARROW_GANDIVA=ON [default=OFF]
# --       Build the Gandiva libraries
# --   ARROW_HDFS=ON [default=OFF]
# --       Build the Arrow HDFS bridge
# --   ARROW_HIVESERVER2=OFF [default=OFF]
# --       Build the HiveServer2 client and Arrow adapter
# --   ARROW_IPC=ON [default=ON]
# --       Build the Arrow IPC extensions
# --   ARROW_JEMALLOC=ON [default=ON]
# --       Build the Arrow jemalloc-based allocator
# --   ARROW_JNI=OFF [default=OFF]
# --       Build the Arrow JNI lib
# --   ARROW_JSON=ON [default=OFF]
# --       Build Arrow with JSON support (requires RapidJSON)
# --   ARROW_MIMALLOC=OFF [default=OFF]
# --       Build the Arrow mimalloc-based allocator
# --   ARROW_PARQUET=ON [default=OFF]
# --       Build the Parquet libraries
# --   ARROW_ORC=OFF [default=OFF]
# --       Build the Arrow ORC adapter
# --   ARROW_PLASMA=OFF [default=OFF]
# --       Build the plasma object store along with Arrow
# --   ARROW_PLASMA_JAVA_CLIENT=OFF [default=OFF]
# --       Build the plasma object store java client
# --   ARROW_PYTHON=ON [default=OFF]
# --       Build the Arrow CPython extensions
# --   ARROW_S3=OFF [default=OFF]
# --       Build Arrow with S3 support (requires the AWS SDK for C++)
# --   ARROW_TENSORFLOW=OFF [default=OFF]
# --       Build Arrow with TensorFlow support enabled
# --   ARROW_TESTING=OFF [default=OFF]
# --       Build the Arrow testing libraries
# --
# -- Thirdparty toolchain options:
# --
# --   ARROW_DEPENDENCY_SOURCE=BUNDLED [default=AUTO|BUNDLED|SYSTEM|CONDA|VCPKG|BREW]
# --       Method to use for acquiring arrow's build dependencies
# --   ARROW_VERBOSE_THIRDPARTY_BUILD=OFF [default=OFF]
# --       Show output from ExternalProjects rather than just logging to files
# --   ARROW_DEPENDENCY_USE_SHARED=ON [default=ON]
# --       Link to shared libraries
# --   ARROW_BOOST_USE_SHARED=ON [default=ON]
# --       Rely on boost shared libraries where relevant
# --   ARROW_BROTLI_USE_SHARED=ON [default=ON]
# --       Rely on Brotli shared libraries where relevant
# --   ARROW_BZ2_USE_SHARED=ON [default=ON]
# --       Rely on Bz2 shared libraries where relevant
# --   ARROW_GFLAGS_USE_SHARED=ON [default=ON]
# --       Rely on GFlags shared libraries where relevant
# --   ARROW_GRPC_USE_SHARED=ON [default=ON]
# --       Rely on gRPC shared libraries where relevant
# --   ARROW_LZ4_USE_SHARED=ON [default=ON]
# --       Rely on lz4 shared libraries where relevant
# --   ARROW_OPENSSL_USE_SHARED=ON [default=ON]
# --       Rely on OpenSSL shared libraries where relevant
# --   ARROW_PROTOBUF_USE_SHARED=ON [default=ON]
# --       Rely on Protocol Buffers shared libraries where relevant
# --   ARROW_THRIFT_USE_SHARED=ON [default=ON]
# --       Rely on thrift shared libraries where relevant
# --   ARROW_UTF8PROC_USE_SHARED=ON [default=ON]
# --       Rely on utf8proc shared libraries where relevant
# --   ARROW_SNAPPY_USE_SHARED=ON [default=ON]
# --       Rely on snappy shared libraries where relevant
# --   ARROW_UTF8PROC_USE_SHARED=ON [default=ON]
# --       Rely on utf8proc shared libraries where relevant
# --   ARROW_ZSTD_USE_SHARED=ON [default=ON]
# --       Rely on zstd shared libraries where relevant
# --   ARROW_USE_GLOG=OFF [default=OFF]
# --       Build libraries with glog support for pluggable logging
# --   ARROW_WITH_BACKTRACE=ON [default=ON]
# --       Build with backtrace support
# --   ARROW_WITH_BROTLI=ON [default=OFF]
# --       Build with Brotli compression
# --   ARROW_WITH_BZ2=ON [default=OFF]
# --       Build with BZ2 compression
# --   ARROW_WITH_LZ4=ON [default=OFF]
# --       Build with lz4 compression
# --   ARROW_WITH_SNAPPY=ON [default=OFF]
# --       Build with Snappy compression
# --   ARROW_WITH_ZLIB=ON [default=OFF]
# --       Build with zlib compression
# --   ARROW_WITH_ZSTD=ON [default=OFF]
# --       Build with zstd compression
# --   ARROW_WITH_UTF8PROC=ON [default=ON]
# --       Build with support for Unicode properties using the utf8proc library
# --       (only used if ARROW_COMPUTE is ON)
# --   ARROW_WITH_RE2=ON [default=ON]
# --       Build with support for regular expressions using the re2 library
# --       (only used if ARROW_COMPUTE or ARROW_GANDIVA is ON)
# --
# -- Parquet options:
# --
# --   PARQUET_MINIMAL_DEPENDENCY=OFF [default=OFF]
# --       Depend only on Thirdparty headers to build libparquet.
# --       Always OFF if building binaries
# --   PARQUET_BUILD_EXECUTABLES=OFF [default=OFF]
# --       Build the Parquet executable CLI tools. Requires static libraries to be built.
# --   PARQUET_BUILD_EXAMPLES=OFF [default=OFF]
# --       Build the Parquet examples. Requires static libraries to be built.
# --   PARQUET_REQUIRE_ENCRYPTION=OFF [default=OFF]
# --       Build support for encryption. Fail if OpenSSL is not found
# --
# -- Gandiva options:
# --
# --   ARROW_GANDIVA_JAVA=OFF [default=OFF]
# --       Build the Gandiva JNI wrappers
# --   ARROW_GANDIVA_STATIC_LIBSTDCPP=OFF [default=OFF]
# --       Include -static-libstdc++ -static-libgcc when linking with
# --       Gandiva static libraries
# --   ARROW_GANDIVA_PC_CXX_FLAGS="" [default=""]
# --       Compiler flags to append when pre-compiling Gandiva operations
# --
# -- Advanced developer options:
# --
# --   ARROW_EXTRA_ERROR_CONTEXT=OFF [default=OFF]
# --       Compile with extra error context (line numbers, code)
# --   ARROW_OPTIONAL_INSTALL=OFF [default=OFF]
# --       If enabled install ONLY targets that have already been built. Please be
# --       advised that if this is enabled 'install' will fail silently on components
# --       that have not been built
# --   Outputting build configuration summary to /arrow/arrow-cpp-build/cmake_summary.json
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /arrow/arrow-cpp-build
# Consolidate compiler generated dependencies of target arrow_dataset_objlib
# [  1%] Performing update step for 'lz4_ep'
# [  3%] Built target zstd_ep
# [  5%] Built target snappy_ep
# [  7%] Built target boost_ep
# [  9%] Built target jemalloc_ep
# [ 11%] Built target brotli_ep
# [ 13%] Built target rapidjson_ep
# [ 15%] Built target bzip2_ep
# [ 16%] Generating ../precompiled_bitcode.cc
# [ 19%] Built target protobuf_ep
# [ 20%] Built target xsimd_ep
# [ 22%] Built target re2_ep
# [ 24%] Built target zlib_ep
# [ 26%] Built target utf8proc_ep
# [ 26%] No patch step for 'lz4_ep'
# [ 28%] Built target thrift_ep
# [ 28%] No configure step for 'lz4_ep'
# [ 28%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/dataset.cc.o
# [ 28%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/discovery.cc.o
# [ 28%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/expression.cc.o
# [ 29%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/file_base.cc.o
# [ 29%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/file_ipc.cc.o
# [ 29%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/projector.cc.o
# [ 29%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/partition.cc.o
# [ 29%] Performing build step for 'lz4_ep'
# [ 29%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/file_csv.cc.o
# [ 30%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/scanner.cc.o
# [ 30%] Building CXX object src/arrow/dataset/CMakeFiles/arrow_dataset_objlib.dir/file_parquet.cc.o
# [ 32%] Built target precompiled
# -- lz4_ep build command succeeded.  See also /arrow/arrow-cpp-build/lz4_ep-prefix/src/lz4_ep-stamp/lz4_ep-build-*.log
# [ 32%] No install step for 'lz4_ep'
# [ 32%] Completed 'lz4_ep'
# [ 33%] Built target lz4_ep
# [ 33%] Built target arrow_bundled_dependencies
# [ 33%] Built target toolchain
# [ 33%] Built target arrow_dependencies
# Consolidate compiler generated dependencies of target arrow_python_objlib
# Consolidate compiler generated dependencies of target gandiva_objlib
# [ 33%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/arrow_to_pandas.cc.o
# [ 34%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/benchmark.cc.o
# [ 34%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/common.cc.o
# [ 34%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/datetime.cc.o
# Consolidate compiler generated dependencies of target arrow_objlib
# [ 34%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/annotator.cc.o
# [ 34%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/array_base.cc.o
# [ 34%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/array_binary.cc.o
# [ 34%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/decimal.cc.o
# [ 35%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/deserialize.cc.o
# [ 35%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/extension_type.cc.o
# [ 35%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/array_decimal.cc.o
# [ 35%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/helpers.cc.o
# [ 35%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/inference.cc.o
# [ 36%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/bitmap_accumulator.cc.o
# [ 36%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/cache.cc.o
# [ 37%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/array_dict.cc.o
# [ 37%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/array_nested.cc.o
# [ 38%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/init.cc.o
# [ 38%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/cast_time.cc.o
# [ 38%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/io.cc.o
# [ 38%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/ipc.cc.o
# [ 38%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/numpy_convert.cc.o
# [ 39%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/numpy_to_arrow.cc.o
# [ 39%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/python_to_arrow.cc.o
# [ 39%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/pyarrow.cc.o
# [ 39%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/configuration.cc.o
# [ 40%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/context_helper.cc.o
# [ 40%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/serialize.cc.o
# [ 40%] Building CXX object src/arrow/python/CMakeFiles/arrow_python_objlib.dir/filesystem.cc.o
# [ 40%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/decimal_ir.cc.o
# [ 40%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/array_primitive.cc.o
# [ 40%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_adaptive.cc.o
# [ 40%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_base.cc.o
# [ 41%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_binary.cc.o
# [ 41%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_decimal.cc.o
# [ 41%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_dict.cc.o
# [ 41%] Built target arrow_dataset_objlib
# [ 41%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_nested.cc.o
# [ 42%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_primitive.cc.o
# [ 42%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/builder_union.cc.o
# [ 42%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/concatenate.cc.o
# [ 42%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/data.cc.o
# [ 43%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/diff.cc.o
# [ 43%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/util.cc.o
# [ 43%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/array/validate.cc.o
# [ 43%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/builder.cc.o
# [ 44%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/buffer.cc.o
# [ 44%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/decimal_type_util.cc.o
# [ 44%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/chunked_array.cc.o
# [ 44%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compare.cc.o
# [ 44%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/config.cc.o
# [ 45%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/datum.cc.o
# [ 45%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/device.cc.o
# [ 45%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/extension_type.cc.o
# [ 45%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/decimal_xlarge.cc.o
# [ 45%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/engine.cc.o
# [ 46%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/date_utils.cc.o
# [ 46%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/memory_pool.cc.o
# [ 46%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/expr_decomposer.cc.o
# [ 46%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/pretty_print.cc.o
# [ 47%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/record_batch.cc.o
# [ 47%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/result.cc.o
# [ 47%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/expr_validator.cc.o
# [ 47%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/scalar.cc.o
# [ 47%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/sparse_tensor.cc.o
# [ 48%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/status.cc.o
# [ 48%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/table.cc.o
# [ 48%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/table_builder.cc.o
# [ 48%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/tensor.cc.o
# [ 48%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/expression.cc.o
# [ 49%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/tensor/coo_converter.cc.o
# [ 49%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/tensor/csf_converter.cc.o
# [ 49%] Built target arrow_python_objlib
# [ 49%] Linking CXX static library ../../../debug/libarrow_python.a
# [ 49%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/tensor/csx_converter.cc.o
# [ 49%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/type.cc.o
# [ 49%] Built target arrow_python_static
# [ 50%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/visitor.cc.o
# [ 50%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/c/bridge.cc.o
# [ 50%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/buffered.cc.o
# [ 50%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/caching.cc.o
# [ 51%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/expression_registry.cc.o
# [ 51%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/compressed.cc.o
# [ 52%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/file.cc.o
# [ 52%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/hdfs.cc.o
# [ 52%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/hdfs_internal.cc.o
# [ 52%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/interfaces.cc.o
# [ 53%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/memory.cc.o
# [ 53%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/slow.cc.o
# [ 53%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/io/transform.cc.o
# [ 53%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/basic_decimal.cc.o
# [ 54%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bit_block_counter.cc.o
# [ 54%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/exported_funcs_registry.cc.o
# [ 54%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/filter.cc.o
# [ 54%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bit_run_reader.cc.o
# [ 54%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bit_util.cc.o
# [ 54%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bitmap.cc.o
# [ 55%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bitmap_builders.cc.o
# [ 55%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bitmap_ops.cc.o
# [ 55%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bpacking.cc.o
# [ 55%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/cancel.cc.o
# [ 56%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression.cc.o
# [ 56%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/cpu_info.cc.o
# [ 56%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/decimal.cc.o
# [ 56%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_ir_builder.cc.o
# [ 56%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/delimiting.cc.o
# [ 56%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/formatting.cc.o
# [ 57%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/future.cc.o
# [ 57%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/int_util.cc.o
# [ 57%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/io_util.cc.o
# [ 57%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/logging.cc.o
# [ 58%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/key_value_metadata.cc.o
# [ 59%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry.cc.o
# [ 59%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/memory.cc.o
# [ 59%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/mutex.cc.o
# [ 59%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/string.cc.o
# [ 60%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/string_builder.cc.o
# [ 60%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_arithmetic.cc.o
# [ 60%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/task_group.cc.o
# [ 60%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/tdigest.cc.o
# [ 60%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/thread_pool.cc.o
# [ 61%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/time.cc.o
# [ 61%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/trie.cc.o
# [ 61%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/utf8.cc.o
# [ 61%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/uri.cc.o
# [ 61%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/value_parsing.cc.o
# [ 62%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/base64.cpp.o
# [ 62%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/datetime/tz.cpp.o
# [ 62%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/bignum.cc.o
# [ 62%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/double-conversion.cc.o
# [ 63%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/bignum-dtoa.cc.o
# [ 63%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/fast-dtoa.cc.o
# [ 63%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_datetime.cc.o
# [ 63%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/cached-powers.cc.o
# [ 63%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/fixed-dtoa.cc.o
# [ 64%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/diy-fp.cc.o
# [ 64%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/double-conversion/strtod.cc.o
# [ 64%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bpacking_avx2.cc.o
# [ 64%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/bpacking_avx512.cc.o
# [ 65%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_brotli.cc.o
# [ 65%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_bz2.cc.o
# [ 65%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_hash.cc.o
# [ 65%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_lz4.cc.o
# [ 65%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_snappy.cc.o
# [ 66%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_zlib.cc.o
# [ 66%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_zstd.cc.o
# [ 66%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/converter.cc.o
# [ 66%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/chunker.cc.o
# [ 66%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/column_builder.cc.o
# [ 67%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_math_ops.cc.o
# [ 68%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/column_decoder.cc.o
# [ 68%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/options.cc.o
# [ 68%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/parser.cc.o
# [ 68%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/reader.cc.o
# [ 69%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/csv/writer.cc.o
# [ 69%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_string.cc.o
# [ 69%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/api_aggregate.cc.o
# [ 69%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_tree_path.cc.o
# [ 69%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/api_scalar.cc.o
# [ 69%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/api_vector.cc.o
# [ 70%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/cast.cc.o
# [ 70%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_registry_timestamp_arithmetic.cc.o
# [ 70%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/exec.cc.o
# [ 70%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/function.cc.o
# [ 70%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/function_signature.cc.o
# [ 70%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernel.cc.o
# [ 71%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/registry.cc.o
# [ 72%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/gdv_function_stubs.cc.o
# [ 72%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_basic.cc.o
# [ 72%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_mode.cc.o
# [ 72%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/llvm_generator.cc.o
# [ 72%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/llvm_types.cc.o
# [ 72%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_quantile.cc.o
# [ 72%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/like_holder.cc.o
# [ 73%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/literal_holder.cc.o
# [ 73%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_tdigest.cc.o
# [ 73%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/projector.cc.o
# [ 74%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_var_std.cc.o
# [ 74%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/codegen_internal.cc.o
# [ 74%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/regex_util.cc.o
# [ 74%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/hash_aggregate.cc.o
# [ 74%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_arithmetic.cc.o
# [ 74%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/selection_vector.cc.o
# [ 75%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_boolean.cc.o
# [ 76%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/tree_expr_builder.cc.o
# [ 76%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_cast_boolean.cc.o
# [ 76%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_cast_internal.cc.o
# [ 76%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_cast_nested.cc.o
# [ 77%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_cast_numeric.cc.o
# [ 77%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_cast_string.cc.o
# [ 77%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/to_date_holder.cc.o
# [ 77%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/random_generator_holder.cc.o
# [ 77%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_cast_temporal.cc.o
# [ 77%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_compare.cc.o
# [ 77%] Building CXX object src/gandiva/CMakeFiles/gandiva_objlib.dir/precompiled_bitcode.cc.o
# [ 78%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_nested.cc.o
# [ 78%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_set_lookup.cc.o
# [ 78%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_string.cc.o
# [ 78%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_validity.cc.o
# [ 79%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/scalar_fill_null.cc.o
# [ 79%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/util_internal.cc.o
# [ 79%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/vector_hash.cc.o
# [ 79%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/vector_nested.cc.o
# [ 79%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/vector_selection.cc.o
# [ 80%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/vector_sort.cc.o
# [ 80%] Built target gandiva_objlib
# [ 80%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_basic_avx2.cc.o
# [ 80%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/compute/kernels/aggregate_basic_avx512.cc.o
# [ 80%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/filesystem/filesystem.cc.o
# [ 81%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/filesystem/localfs.cc.o
# [ 81%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/filesystem/mockfs.cc.o
# [ 81%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/filesystem/path_util.cc.o
# [ 81%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/filesystem/util_internal.cc.o
# [ 82%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/filesystem/hdfs.cc.o
# [ 82%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/dictionary.cc.o
# [ 82%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/message.cc.o
# [ 82%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/feather.cc.o
# [ 83%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/metadata_internal.cc.o
# [ 83%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/options.cc.o
# [ 83%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/reader.cc.o
# [ 83%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/writer.cc.o
# [ 83%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/ipc/json_simple.cc.o
# [ 84%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/options.cc.o
# [ 84%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/chunked_builder.cc.o
# [ 84%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/chunker.cc.o
# [ 84%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/converter.cc.o
# [ 85%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/object_parser.cc.o
# [ 85%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/object_writer.cc.o
# [ 85%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/parser.cc.o
# [ 85%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/json/reader.cc.o
# [ 86%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/musl/strptime.c.o
# [ 86%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriCommon.c.o
# [ 86%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriCompare.c.o
# [ 86%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriEscape.c.o
# [ 87%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriFile.c.o
# [ 87%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriIp4.c.o
# [ 87%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriMemory.c.o
# [ 88%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriNormalizeBase.c.o
# [ 88%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriNormalize.c.o
# [ 88%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriParseBase.c.o
# [ 88%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriParse.c.o
# [ 88%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriQuery.c.o
# [ 89%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriRecompose.c.o
# [ 89%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriResolve.c.o
# [ 89%] Building C object src/arrow/CMakeFiles/arrow_objlib.dir/vendored/uriparser/UriShorten.c.o
# [ 89%] Built target arrow_objlib
# [ 89%] Linking CXX static library ../../debug/libarrow.a
# [ 89%] Linking CXX shared library ../../debug/libarrow.so
# [ 89%] Built target arrow_shared
# [ 90%] Linking CXX shared library ../../../debug/libarrow_python.so
# [ 91%] Linking CXX shared library ../../debug/libgandiva.so
# [ 91%] Built target arrow_python_shared
# [ 91%] Built target arrow_static
# [ 91%] Linking CXX static library ../../debug/libgandiva.a
# [ 91%] Built target gandiva_shared
# Consolidate compiler generated dependencies of target parquet_objlib
# [ 91%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/arrow/path_internal.cc.o
# [ 91%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/arrow/reader.cc.o
# [ 91%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/arrow/reader_internal.cc.o
# [ 92%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/arrow/schema.cc.o
# [ 92%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/arrow/schema_internal.cc.o
# [ 92%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/arrow/writer.cc.o
# [ 92%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/bloom_filter.cc.o
# [ 92%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/column_reader.cc.o
# [ 93%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/column_scanner.cc.o
# [ 93%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/column_writer.cc.o
# [ 93%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/encoding.cc.o
# [ 94%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/encryption/internal_file_decryptor.cc.o
# [ 94%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/encryption/encryption.cc.o
# [ 94%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/encryption/internal_file_encryptor.cc.o
# [ 94%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/exception.cc.o
# [ 94%] Built target gandiva_static
# [ 94%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/file_reader.cc.o
# [ 95%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/file_writer.cc.o
# [ 95%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/level_comparison.cc.o
# [ 95%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/level_conversion.cc.o
# [ 95%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/metadata.cc.o
# [ 96%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/murmur3.cc.o
# [ 96%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/__/generated/parquet_constants.cpp.o
# [ 96%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/__/generated/parquet_types.cpp.o
# [ 96%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/platform.cc.o
# [ 97%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/printer.cc.o
# [ 97%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/properties.cc.o
# [ 97%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/schema.cc.o
# [ 97%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/statistics.cc.o
# [ 97%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/stream_reader.cc.o
# [ 98%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/stream_writer.cc.o
# [ 98%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/types.cc.o
# [ 98%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/level_comparison_avx2.cc.o
# [ 98%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/level_conversion_bmi2.cc.o
# [ 99%] Building CXX object src/parquet/CMakeFiles/parquet_objlib.dir/encryption/encryption_internal_nossl.cc.o
# [ 99%] Built target parquet_objlib
# [ 99%] Linking CXX static library ../../debug/libparquet.a
# [ 99%] Linking CXX shared library ../../debug/libparquet.so
# [ 99%] Built target parquet_static
# [100%] Linking CXX static library ../../../debug/libarrow_dataset.a
# [100%] Built target arrow_dataset_static
# [100%] Built target parquet_shared
# [100%] Linking CXX shared library ../../../debug/libarrow_dataset.so
# [100%] Built target arrow_dataset_shared
# [  2%] Built target jemalloc_ep
# [  4%] Built target zstd_ep
# [  6%] Built target snappy_ep
# [  8%] Built target brotli_ep
# [ 10%] Built target boost_ep
# [ 12%] Built target thrift_ep
# [ 14%] Built target rapidjson_ep
# [ 16%] Built target bzip2_ep
# [ 18%] Built target protobuf_ep
# [ 19%] Performing update step for 'lz4_ep'
# [ 19%] No patch step for 'lz4_ep'
# [ 19%] No configure step for 'lz4_ep'
# [ 19%] Performing build step for 'lz4_ep'
# -- lz4_ep build command succeeded.  See also /arrow/arrow-cpp-build/lz4_ep-prefix/src/lz4_ep-stamp/lz4_ep-build-*.log
# [ 19%] No install step for 'lz4_ep'
# [ 19%] Completed 'lz4_ep'
# [ 20%] Built target lz4_ep
# [ 22%] Built target xsimd_ep
# [ 24%] Built target zlib_ep
# [ 26%] Built target re2_ep
# [ 28%] Built target utf8proc_ep
# [ 28%] Built target arrow_bundled_dependencies
# [ 28%] Built target toolchain
# [ 28%] Built target arrow_dependencies
# Consolidate compiler generated dependencies of target arrow_objlib
# [ 28%] Building CXX object src/arrow/CMakeFiles/arrow_objlib.dir/util/compression_lz4.cc.o
# [ 71%] Built target arrow_objlib
# [ 71%] Linking CXX shared library ../../debug/libarrow.so
# [ 71%] Built target arrow_shared
# [ 71%] Linking CXX static library ../../debug/libarrow.a
# [ 71%] Built target arrow_static
# Consolidate compiler generated dependencies of target arrow_dataset_objlib
# [ 73%] Built target arrow_dataset_objlib
# Consolidate compiler generated dependencies of target parquet_objlib
# [ 81%] Built target parquet_objlib
# [ 81%] Linking CXX shared library ../../debug/libparquet.so
# [ 81%] Built target parquet_shared
# [ 81%] Linking CXX shared library ../../../debug/libarrow_dataset.so
# [ 81%] Built target arrow_dataset_shared
# [ 81%] Built target parquet_static
# [ 82%] Built target arrow_dataset_static
# Consolidate compiler generated dependencies of target arrow_python_objlib
# [ 86%] Built target arrow_python_objlib
# [ 87%] Linking CXX shared library ../../../debug/libarrow_python.so
# [ 87%] Built target arrow_python_shared
# [ 87%] Built target arrow_python_static
# [ 90%] Built target precompiled
# Consolidate compiler generated dependencies of target gandiva_objlib
# [ 99%] Built target gandiva_objlib
# [100%] Linking CXX shared library ../../debug/libgandiva.so
# [100%] Built target gandiva_shared
# [100%] Built target gandiva_static
# Install the project...
# -- Install configuration: "DEBUG"
# -- Up-to-date: /arrow/dist/include/arrow/util/config.h
# -- Up-to-date: /arrow/dist/share/doc/arrow/LICENSE.txt
# -- Up-to-date: /arrow/dist/share/doc/arrow/NOTICE.txt
# -- Up-to-date: /arrow/dist/share/doc/arrow/README.md
# -- Installing: /arrow/dist/lib/libarrow.so.400.0.0
# -- Up-to-date: /arrow/dist/lib/libarrow.so.400
# -- Up-to-date: /arrow/dist/lib/libarrow.so
# -- Installing: /arrow/dist/lib/libarrow.a
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/FindArrow.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/ArrowTargets.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/ArrowTargets-debug.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/ArrowConfig.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/ArrowConfigVersion.cmake
# -- Up-to-date: /arrow/dist/lib/pkgconfig/arrow.pc
# -- Up-to-date: /arrow/dist/lib/libarrow_bundled_dependencies.a
# -- Up-to-date: /arrow/dist/include/arrow/api.h
# -- Up-to-date: /arrow/dist/include/arrow/array.h
# -- Up-to-date: /arrow/dist/include/arrow/buffer.h
# -- Up-to-date: /arrow/dist/include/arrow/buffer_builder.h
# -- Up-to-date: /arrow/dist/include/arrow/builder.h
# -- Up-to-date: /arrow/dist/include/arrow/chunked_array.h
# -- Up-to-date: /arrow/dist/include/arrow/compare.h
# -- Up-to-date: /arrow/dist/include/arrow/config.h
# -- Up-to-date: /arrow/dist/include/arrow/datum.h
# -- Up-to-date: /arrow/dist/include/arrow/device.h
# -- Up-to-date: /arrow/dist/include/arrow/extension_type.h
# -- Up-to-date: /arrow/dist/include/arrow/memory_pool.h
# -- Up-to-date: /arrow/dist/include/arrow/memory_pool_test.h
# -- Up-to-date: /arrow/dist/include/arrow/pch.h
# -- Up-to-date: /arrow/dist/include/arrow/pretty_print.h
# -- Up-to-date: /arrow/dist/include/arrow/record_batch.h
# -- Up-to-date: /arrow/dist/include/arrow/result.h
# -- Up-to-date: /arrow/dist/include/arrow/scalar.h
# -- Up-to-date: /arrow/dist/include/arrow/sparse_tensor.h
# -- Up-to-date: /arrow/dist/include/arrow/status.h
# -- Up-to-date: /arrow/dist/include/arrow/stl.h
# -- Up-to-date: /arrow/dist/include/arrow/stl_allocator.h
# -- Up-to-date: /arrow/dist/include/arrow/stl_iterator.h
# -- Up-to-date: /arrow/dist/include/arrow/table.h
# -- Up-to-date: /arrow/dist/include/arrow/table_builder.h
# -- Up-to-date: /arrow/dist/include/arrow/tensor.h
# -- Up-to-date: /arrow/dist/include/arrow/type.h
# -- Up-to-date: /arrow/dist/include/arrow/type_fwd.h
# -- Up-to-date: /arrow/dist/include/arrow/type_traits.h
# -- Up-to-date: /arrow/dist/include/arrow/visitor.h
# -- Up-to-date: /arrow/dist/include/arrow/visitor_inline.h
# -- Installing: /arrow/dist/lib/cmake/arrow/ArrowOptions.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/arrow-config.cmake
# -- Up-to-date: /arrow/dist/include/arrow/testing/extension_type.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/future_util.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/generator.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/gtest_common.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/gtest_compat.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/gtest_util.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/json_integration.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/macros.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/pch.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/random.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/util.h
# -- Up-to-date: /arrow/dist/include/arrow/testing/visibility.h
# -- Up-to-date: /arrow/dist/include/arrow/array/array_base.h
# -- Up-to-date: /arrow/dist/include/arrow/array/array_binary.h
# -- Up-to-date: /arrow/dist/include/arrow/array/array_decimal.h
# -- Up-to-date: /arrow/dist/include/arrow/array/array_dict.h
# ...
# -- Up-to-date: /arrow/dist/include/parquet/schema.h
# -- Up-to-date: /arrow/dist/include/parquet/statistics.h
# -- Up-to-date: /arrow/dist/include/parquet/stream_reader.h
# -- Up-to-date: /arrow/dist/include/parquet/stream_writer.h
# -- Up-to-date: /arrow/dist/include/parquet/test_util.h
# -- Up-to-date: /arrow/dist/include/parquet/type_fwd.h
# -- Up-to-date: /arrow/dist/include/parquet/types.h
# -- Up-to-date: /arrow/dist/include/parquet/windows_compatibility.h
# -- Up-to-date: /arrow/dist/include/parquet/parquet_version.h
# -- Up-to-date: /arrow/dist/include/parquet/api/io.h
# -- Up-to-date: /arrow/dist/include/parquet/api/reader.h
# -- Up-to-date: /arrow/dist/include/parquet/api/schema.h
# -- Up-to-date: /arrow/dist/include/parquet/api/writer.h
# -- Up-to-date: /arrow/dist/include/parquet/arrow/reader.h
# -- Up-to-date: /arrow/dist/include/parquet/arrow/schema.h
# -- Up-to-date: /arrow/dist/include/parquet/arrow/test_util.h
# -- Up-to-date: /arrow/dist/include/parquet/arrow/writer.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/crypto_factory.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/encryption.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/file_key_material_store.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/file_key_unwrapper.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/file_key_wrapper.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/key_encryption_key.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/key_material.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/key_metadata.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/key_toolkit.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/kms_client.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/kms_client_factory.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/local_wrap_kms_client.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/test_encryption_util.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/test_in_memory_kms.h
# -- Up-to-date: /arrow/dist/include/parquet/encryption/two_level_cache_with_expiration.h
# -- Installing: /arrow/dist/lib/libgandiva.so.400.0.0
# -- Up-to-date: /arrow/dist/lib/libgandiva.so.400
# -- Set runtime path of "/arrow/dist/lib/libgandiva.so.400.0.0" to ""
# -- Up-to-date: /arrow/dist/lib/libgandiva.so
# -- Installing: /arrow/dist/lib/libgandiva.a
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/FindGandiva.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/GandivaTargets.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/GandivaTargets-debug.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/GandivaConfig.cmake
# -- Up-to-date: /arrow/dist/lib/cmake/arrow/GandivaConfigVersion.cmake
# -- Up-to-date: /arrow/dist/lib/pkgconfig/gandiva.pc
# -- Up-to-date: /arrow/dist/include/gandiva/annotator.h
# -- Up-to-date: /arrow/dist/include/gandiva/arrow.h
# -- Up-to-date: /arrow/dist/include/gandiva/basic_decimal_scalar.h
# -- Up-to-date: /arrow/dist/include/gandiva/bitmap_accumulator.h
# -- Up-to-date: /arrow/dist/include/gandiva/cache.h
# -- Up-to-date: /arrow/dist/include/gandiva/compiled_expr.h
# -- Up-to-date: /arrow/dist/include/gandiva/condition.h
# -- Up-to-date: /arrow/dist/include/gandiva/configuration.h
# -- Up-to-date: /arrow/dist/include/gandiva/date_utils.h
# -- Up-to-date: /arrow/dist/include/gandiva/decimal_ir.h
# -- Up-to-date: /arrow/dist/include/gandiva/decimal_scalar.h
# -- Up-to-date: /arrow/dist/include/gandiva/decimal_type_util.h
# -- Up-to-date: /arrow/dist/include/gandiva/decimal_xlarge.h
# -- Up-to-date: /arrow/dist/include/gandiva/dex.h
# -- Up-to-date: /arrow/dist/include/gandiva/dex_visitor.h
# -- Up-to-date: /arrow/dist/include/gandiva/engine.h
# -- Up-to-date: /arrow/dist/include/gandiva/eval_batch.h
# -- Up-to-date: /arrow/dist/include/gandiva/execution_context.h
# -- Up-to-date: /arrow/dist/include/gandiva/exported_funcs.h
# -- Up-to-date: /arrow/dist/include/gandiva/exported_funcs_registry.h
# -- Up-to-date: /arrow/dist/include/gandiva/expr_decomposer.h
# -- Up-to-date: /arrow/dist/include/gandiva/expr_validator.h
# -- Up-to-date: /arrow/dist/include/gandiva/expression.h
# -- Up-to-date: /arrow/dist/include/gandiva/expression_registry.h
# -- Up-to-date: /arrow/dist/include/gandiva/field_descriptor.h
# -- Up-to-date: /arrow/dist/include/gandiva/filter.h
# -- Up-to-date: /arrow/dist/include/gandiva/func_descriptor.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_holder_registry.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_ir_builder.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_arithmetic.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_common.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_datetime.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_hash.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_math_ops.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_string.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_timestamp_arithmetic.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_registry_tree_path.h
# -- Up-to-date: /arrow/dist/include/gandiva/function_signature.h
# -- Up-to-date: /arrow/dist/include/gandiva/gandiva_aliases.h
# -- Up-to-date: /arrow/dist/include/gandiva/gdv_function_stubs.h
# -- Up-to-date: /arrow/dist/include/gandiva/in_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/like_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/literal_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/llvm_generator.h
# -- Up-to-date: /arrow/dist/include/gandiva/llvm_includes.h
# -- Up-to-date: /arrow/dist/include/gandiva/llvm_types.h
# -- Up-to-date: /arrow/dist/include/gandiva/local_bitmaps_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/lru_cache.h
# -- Up-to-date: /arrow/dist/include/gandiva/lvalue.h
# -- Up-to-date: /arrow/dist/include/gandiva/native_function.h
# -- Up-to-date: /arrow/dist/include/gandiva/node.h
# -- Up-to-date: /arrow/dist/include/gandiva/node_visitor.h
# -- Up-to-date: /arrow/dist/include/gandiva/pch.h
# -- Up-to-date: /arrow/dist/include/gandiva/projector.h
# -- Up-to-date: /arrow/dist/include/gandiva/random_generator_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/regex_util.h
# -- Up-to-date: /arrow/dist/include/gandiva/selection_vector.h
# -- Up-to-date: /arrow/dist/include/gandiva/selection_vector_impl.h
# -- Up-to-date: /arrow/dist/include/gandiva/simple_arena.h
# -- Up-to-date: /arrow/dist/include/gandiva/to_date_holder.h
# -- Up-to-date: /arrow/dist/include/gandiva/tree_expr_builder.h
# -- Up-to-date: /arrow/dist/include/gandiva/value_validity_pair.h
# -- Up-to-date: /arrow/dist/include/gandiva/visibility.h
# /app/applications/jupyter-extension/nteract_on_jupyter/notebooks
# /arrow/python /app/applications/jupyter-extension/nteract_on_jupyter/notebooks
# /usr/local/lib/python3.9/site-packages/setuptools/dist.py:481: UserWarning: The version specified ('yes') is an invalid version, this may not work as expected with newer versions of setuptools, pip, and PyPI. Please see PEP 440 for more details.
#   warnings.warn(
# running develop
# running egg_info
# writing pyarrow.egg-info/PKG-INFO
# writing dependency_links to pyarrow.egg-info/dependency_links.txt
# writing entry points to pyarrow.egg-info/entry_points.txt
# writing requirements to pyarrow.egg-info/requires.txt
# writing top-level names to pyarrow.egg-info/top_level.txt
# reading manifest file 'pyarrow.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '*~' found anywhere in distribution
# warning: no previously-included files matching '#*' found anywhere in distribution
# warning: no previously-included files matching '.git*' found anywhere in distribution
# warning: no previously-included files matching '.DS_Store' found anywhere in distribution
# no previously-included directories found matching '.asv'
# writing manifest file 'pyarrow.egg-info/SOURCES.txt'
# running build_ext
# -- Running cmake for pyarrow
# cmake -DPYTHON_EXECUTABLE=/usr/local/bin/python3 -DPython3_EXECUTABLE=/usr/local/bin/python3  -DPYARROW_BUILD_CUDA=off -DPYARROW_BUILD_FLIGHT=off -DPYARROW_BUILD_GANDIVA=on -DPYARROW_BUILD_DATASET=on -DPYARROW_BUILD_ORC=off -DPYARROW_BUILD_PARQUET=on -DPYARROW_BUILD_PLASMA=off -DPYARROW_BUILD_S3=off -DPYARROW_BUILD_HDFS=off -DPYARROW_USE_TENSORFLOW=off -DPYARROW_BUNDLE_ARROW_CPP=off -DPYARROW_BUNDLE_BOOST=off -DPYARROW_GENERATE_COVERAGE=off -DPYARROW_BOOST_USE_SHARED=on -DPYARROW_PARQUET_USE_SHARED=on -DCMAKE_BUILD_TYPE=debug /arrow/python
# -- System processor: x86_64
# -- Arrow build warning level: PRODUCTION
# Using ld linker
# Configured for DEBUG build (set with cmake -DCMAKE_BUILD_TYPE={release,debug,...})
# -- Build Type: DEBUG
# -- Generator: Unix Makefiles
# -- Build output directory: /arrow/python/build/temp.linux-x86_64-3.9/debug
# CMake Warning (dev) at /opt/cmake/share/cmake-3.20/Modules/FindPackageHandleStandardArgs.cmake:438 (message):
#   The package name passed to `find_package_handle_standard_args` (PkgConfig)
#   does not match the name of the calling package (Arrow).  This can lead to
#   problems in calling code that expects `find_package` result variables
#   (e.g., `_FOUND`) to follow a certain pattern.
# Call Stack (most recent call first):
#   /opt/cmake/share/cmake-3.20/Modules/FindPkgConfig.cmake:70 (find_package_handle_standard_args)
#   cmake_modules/FindArrow.cmake:39 (include)
#   cmake_modules/FindArrowPython.cmake:46 (find_package)
#   CMakeLists.txt:218 (find_package)
# This warning is for project developers.  Use -Wno-dev to suppress it.
#
# -- Arrow version: 4.0.0 (HOME: /arrow/dist)
# -- Arrow SO and ABI version: 400
# -- Arrow full SO version: 400.0.0
# -- Found the Arrow core shared library: /arrow/dist/lib/libarrow.so
# -- Found the Arrow core import library: /arrow/dist/lib/libarrow.so
# -- Found the Arrow core static library: /arrow/dist/lib/libarrow.a
# -- Found the Arrow Python by HOME: /arrow/dist
# -- Found the Arrow Python shared library: /arrow/dist/lib/libarrow_python.so
# -- Found the Arrow Python import library: /arrow/dist/lib/libarrow_python.so
# -- Found the Arrow Python static library: /arrow/dist/lib/libarrow_python.a
# -- Parquet version: 4.0.0 (HOME: /arrow/dist)
# -- Found the Parquet shared library: /arrow/dist/lib/libparquet.so
# -- Found the Parquet import library: /arrow/dist/lib/libparquet.so
# -- Found the Parquet static library: /arrow/dist/lib/libparquet.a
# -- Found the Arrow Dataset by HOME: /arrow/dist
# -- Found the Arrow Dataset shared library: /arrow/dist/lib/libarrow_dataset.so
# -- Found the Arrow Dataset import library: /arrow/dist/lib/libarrow_dataset.so
# -- Found the Arrow Dataset static library: /arrow/dist/lib/libarrow_dataset.a
# -- Found the Gandiva by HOME: /arrow/dist
# -- Found the Gandiva shared library: /arrow/dist/lib/libgandiva.so
# -- Found the Gandiva import library: /arrow/dist/lib/libgandiva.so
# -- Found the Gandiva static library: /arrow/dist/lib/libgandiva.a
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /arrow/python/build/temp.linux-x86_64-3.9
# -- Finished cmake for pyarrow
# -- Running cmake --build for pyarrow
# cmake --build . --config debug --
# [  4%] Compiling Cython CXX source for gandiva...
# [  4%] Built target gandiva_pyx
# Consolidate compiler generated dependencies of target gandiva
# [  8%] Building CXX object CMakeFiles/gandiva.dir/gandiva.cpp.o
# [ 12%] Linking CXX shared module debug/gandiva.cpython-39-x86_64-linux-gnu.so
# [ 12%] Built target gandiva
# [ 16%] Compiling Cython CXX source for _dataset...
# [ 16%] Built target _dataset_pyx
# Consolidate compiler generated dependencies of target _dataset
# [ 20%] Building CXX object CMakeFiles/_dataset.dir/_dataset.cpp.o
# [ 25%] Linking CXX shared module debug/_dataset.cpython-39-x86_64-linux-gnu.so
# [ 25%] Built target _dataset
# [ 29%] Compiling Cython CXX source for _fs...
# [ 29%] Built target _fs_pyx
# Consolidate compiler generated dependencies of target _fs
# [ 33%] Building CXX object CMakeFiles/_fs.dir/_fs.cpp.o
# [ 37%] Linking CXX shared module debug/_fs.cpython-39-x86_64-linux-gnu.so
# [ 37%] Built target _fs
# [ 41%] Compiling Cython CXX source for lib...
# [ 41%] Built target lib_pyx
# Consolidate compiler generated dependencies of target lib
# [ 45%] Building CXX object CMakeFiles/lib.dir/lib.cpp.o
# [ 50%] Linking CXX shared module debug/lib.cpython-39-x86_64-linux-gnu.so
# [ 50%] Built target lib
# [ 54%] Compiling Cython CXX source for _csv...
# [ 54%] Built target _csv_pyx
# Consolidate compiler generated dependencies of target _csv
# [ 58%] Building CXX object CMakeFiles/_csv.dir/_csv.cpp.o
# [ 62%] Linking CXX shared module debug/_csv.cpython-39-x86_64-linux-gnu.so
# [ 62%] Built target _csv
# [ 66%] Compiling Cython CXX source for _compute...
# [ 66%] Built target _compute_pyx
# Consolidate compiler generated dependencies of target _compute
# [ 70%] Building CXX object CMakeFiles/_compute.dir/_compute.cpp.o
# [ 75%] Linking CXX shared module debug/_compute.cpython-39-x86_64-linux-gnu.so
# [ 75%] Built target _compute
# [ 79%] Compiling Cython CXX source for _parquet...
# [ 79%] Built target _parquet_pyx
# Consolidate compiler generated dependencies of target _parquet
# [ 83%] Building CXX object CMakeFiles/_parquet.dir/_parquet.cpp.o
# [ 87%] Linking CXX shared module debug/_parquet.cpython-39-x86_64-linux-gnu.so
# [ 87%] Built target _parquet
# [ 91%] Compiling Cython CXX source for _json...
# [ 91%] Built target _json_pyx
# Consolidate compiler generated dependencies of target _json
# [ 95%] Building CXX object CMakeFiles/_json.dir/_json.cpp.o
# [100%] Linking CXX shared module debug/_json.cpython-39-x86_64-linux-gnu.so
# [100%] Built target _json
# -- Finished cmake --build for pyarrow
# Bundling includes: debug/include
# Moving built C-extension debug/lib.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/lib.cpython-39-x86_64-linux-gnu.so
# Moving built C-extension debug/_fs.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/_fs.cpython-39-x86_64-linux-gnu.so
# Moving built C-extension debug/_csv.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/_csv.cpython-39-x86_64-linux-gnu.so
# Moving built C-extension debug/_json.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/_json.cpython-39-x86_64-linux-gnu.so
# Moving built C-extension debug/_compute.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/_compute.cpython-39-x86_64-linux-gnu.so
# Did not find debug/_cuda.cpython-39-x86_64-linux-gnu.so
# Cython module _cuda failure permitted
# Did not find debug/_flight.cpython-39-x86_64-linux-gnu.so
# Cython module _flight failure permitted
# Moving built C-extension debug/_dataset.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/_dataset.cpython-39-x86_64-linux-gnu.so
# Moving built C-extension debug/_parquet.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/_parquet.cpython-39-x86_64-linux-gnu.so
# Did not find debug/_orc.cpython-39-x86_64-linux-gnu.so
# Cython module _orc failure permitted
# Did not find debug/_plasma.cpython-39-x86_64-linux-gnu.so
# Cython module _plasma failure permitted
# Did not find debug/_s3fs.cpython-39-x86_64-linux-gnu.so
# Cython module _s3fs failure permitted
# Did not find debug/_hdfs.cpython-39-x86_64-linux-gnu.so
# Cython module _hdfs failure permitted
# Moving built C-extension debug/gandiva.cpython-39-x86_64-linux-gnu.so to build path /arrow/python/pyarrow/gandiva.cpython-39-x86_64-linux-gnu.so
# Creating /usr/local/lib/python3.9/site-packages/pyarrow.egg-link (link to .)
# pyarrow yes is already the active version in easy-install.pth
# Installing plasma_store script to /usr/local/bin
#
# Installed /arrow/python
# Processing dependencies for pyarrow===yes
# Searching for numpy==1.20.2
# Best match: numpy 1.20.2
# Adding numpy 1.20.2 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.9 script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/site-packages
# Finished processing dependencies for pyarrow===yes
# /app/applications/jupyter-extension/nteract_on_jupyter/notebooks

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.cb.java import *

# SemGrep: httpservlet-path-traversal
query = (
 new() % label_as_match()
 |where| any_arg()
   |isa| call(with_name('getParameter')) % label('because (1)')
   |where| the_receiver()
     |isa| param() % label('because (2)')
     |where| the_type()
       |isa| type_(with_name('URL')) 
)

results = Evaluator(query).evaluate()
display_results(results)
# Out:
# Match (RS#2):
# ```
# new ThreadPoolExecutor(cores, threads, alive, TimeUnit.MILLISECONDS,
#                 queues == 0 ? new SynchronousQueue<Runnable>() :
#                         (queues < 0 ? new LinkedBlockingQueue<Runnable>()
#                                 : new LinkedBlockingQueue<Runnable>(queues)),
#                 new NamedInternalThreadFactory(name, true), new AbortPolicyWithReport(name, url))
# ```
# └─ because (1): ```
#    cores = url.getParameter(CORE_THREADS_KEY, DEFAULT_CORE_THREADS)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new ThreadPoolExecutor(cores, threads, alive, TimeUnit.MILLISECONDS,
#                 queues == 0 ? new SynchronousQueue<Runnable>() :
#                         (queues < 0 ? new LinkedBlockingQueue<Runnable>()
#                                 : new LinkedBlockingQueue<Runnable>(queues)),
#                 new NamedInternalThreadFactory(name, true), new AbortPolicyWithReport(name, url))
# ```
# └─ because (1): ```
#    threads = url.getParameter(THREADS_KEY, Integer.MAX_VALUE)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new ThreadPoolExecutor(cores, threads, alive, TimeUnit.MILLISECONDS,
#                 queues == 0 ? new SynchronousQueue<Runnable>() :
#                         (queues < 0 ? new LinkedBlockingQueue<Runnable>()
#                                 : new LinkedBlockingQueue<Runnable>(queues)),
#                 new NamedInternalThreadFactory(name, true), new AbortPolicyWithReport(name, url))
# ```
# └─ because (1): ```
#    alive = url.getParameter(ALIVE_KEY, DEFAULT_ALIVE)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new LinkedBlockingQueue<Runnable>(queues)
# ```
# └─ because (1): ```
#    queues = url.getParameter(QUEUES_KEY, DEFAULT_QUEUES)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new NamedInternalThreadFactory(name, true)
# ```
# └─ because (1): ```
#    name = url.getParameter(THREAD_NAME_KEY, DEFAULT_THREAD_NAME)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new AbortPolicyWithReport(name, url)
# ```
# └─ because (1): ```
#    name = url.getParameter(THREAD_NAME_KEY, DEFAULT_THREAD_NAME)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new ThreadPoolExecutor(threads, threads, 0, TimeUnit.MILLISECONDS,
#                 queues == 0 ? new SynchronousQueue<Runnable>() :
#                         (queues < 0 ? new LinkedBlockingQueue<Runnable>()
#                                 : new LinkedBlockingQueue<Runnable>(queues)),
#                 new NamedInternalThreadFactory(name, true), new AbortPolicyWithReport(name, url))
# ```
# └─ because (1): ```
#    threads = url.getParameter(THREADS_KEY, DEFAULT_THREADS)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new ThreadPoolExecutor(threads, threads, 0, TimeUnit.MILLISECONDS,
#                 queues == 0 ? new SynchronousQueue<Runnable>() :
#                         (queues < 0 ? new LinkedBlockingQueue<Runnable>()
#                                 : new LinkedBlockingQueue<Runnable>(queues)),
#                 new NamedInternalThreadFactory(name, true), new AbortPolicyWithReport(name, url))
# ```
# └─ because (1): ```
#    threads = url.getParameter(THREADS_KEY, DEFAULT_THREADS)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new LinkedBlockingQueue<Runnable>(queues)
# ```
# └─ because (1): ```
#    queues = url.getParameter(QUEUES_KEY, DEFAULT_QUEUES)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new NamedInternalThreadFactory(name, true)
# ```
# └─ because (1): ```
#    name = url.getParameter(THREAD_NAME_KEY, DEFAULT_THREAD_NAME)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#2):
# ```
# new AbortPolicyWithReport(name, url)
# ```
# └─ because (1): ```
#    name = url.getParameter(THREAD_NAME_KEY, DEFAULT_THREAD_NAME)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Over 10 matches. Stopping early.
# Match (RS#4):
# ```
# new MetadataReportRetry(reportServerURL.getParameter(RETRY_TIMES_KEY, DEFAULT_METADATA_REPORT_RETRY_TIMES),
#                 reportServerURL.getParameter(RETRY_PERIOD_KEY, DEFAULT_METADATA_REPORT_RETRY_PERIOD))
# ```
# └─ because (1): ```
#    reportServerURL.getParameter(RETRY_TIMES_KEY, DEFAULT_METADATA_REPORT_RETRY_TIMES)
#    ```
#  └─ because (2): ```
#     URL reportServerURL
#     ```
# Match (RS#4):
# ```
# new MetadataReportRetry(reportServerURL.getParameter(RETRY_TIMES_KEY, DEFAULT_METADATA_REPORT_RETRY_TIMES),
#                 reportServerURL.getParameter(RETRY_PERIOD_KEY, DEFAULT_METADATA_REPORT_RETRY_PERIOD))
# ```
# └─ because (1): ```
#    reportServerURL.getParameter(RETRY_PERIOD_KEY, DEFAULT_METADATA_REPORT_RETRY_PERIOD)
#    ```
#  └─ because (2): ```
#     URL reportServerURL
#     ```
# Match (RS#4):
# ```
# new MetadataIdentifier(providerUrl.getServiceInterface(),
#                             providerUrl.getParameter(VERSION_KEY), providerUrl.getParameter(GROUP_KEY),
#                             PROVIDER_SIDE, providerUrl.getParameter(APPLICATION_KEY))
# ```
# └─ because (1): ```
#    providerUrl.getParameter(VERSION_KEY)
#    ```
#  └─ because (2): ```
#     URL providerUrl
#     ```
# Match (RS#4):
# ```
# new MetadataIdentifier(providerUrl.getServiceInterface(),
#                             providerUrl.getParameter(VERSION_KEY), providerUrl.getParameter(GROUP_KEY),
#                             PROVIDER_SIDE, providerUrl.getParameter(APPLICATION_KEY))
# ```
# └─ because (1): ```
#    providerUrl.getParameter(GROUP_KEY)
#    ```
#  └─ because (2): ```
#     URL providerUrl
#     ```
# Match (RS#4):
# ```
# new MetadataIdentifier(providerUrl.getServiceInterface(),
#                             providerUrl.getParameter(VERSION_KEY), providerUrl.getParameter(GROUP_KEY),
#                             PROVIDER_SIDE, providerUrl.getParameter(APPLICATION_KEY))
# ```
# └─ because (1): ```
#    providerUrl.getParameter(APPLICATION_KEY)
#    ```
#  └─ because (2): ```
#     URL providerUrl
#     ```
# Match (RS#4):
# ```
# new JedisPool(getConfig(), url.getHost(), url.getPort(),
#                 url.getParameter(TIMEOUT_KEY, DEFAULT_TIMEOUT), url.getPassword())
# ```
# └─ because (1): ```
#    url.getParameter(TIMEOUT_KEY, DEFAULT_TIMEOUT)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#4):
# ```
# new ThreadPoolExecutor(
#                     1
#                     , url.getParameter(ETCD3_NOTIFY_MAXTHREADS_KEYS, DEFAULT_ETCD3_NOTIFY_THREADS)
#                     , DEFAULT_SESSION_TIMEOUT
#                     , TimeUnit.MILLISECONDS
#                     , new LinkedBlockingQueue<Runnable>(url.getParameter(DEFAULT_ETCD3_NOTIFY_QUEUES_KEY, DEFAULT_GRPC_QUEUES * 3))
#                     , new NamedThreadFactory("etcd3-notify", true))
# ```
# └─ because (1): ```
#    url.getParameter(ETCD3_NOTIFY_MAXTHREADS_KEYS, DEFAULT_ETCD3_NOTIFY_THREADS)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#4):
# ```
# new LinkedBlockingQueue<Runnable>(url.getParameter(DEFAULT_ETCD3_NOTIFY_QUEUES_KEY, DEFAULT_GRPC_QUEUES * 3))
# ```
# └─ because (1): ```
#    url.getParameter(DEFAULT_ETCD3_NOTIFY_QUEUES_KEY, DEFAULT_GRPC_QUEUES * 3)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#4):
# ```
# new JedisCluster(nodes, url.getParameter("connection.timeout", DEFAULT_TIMEOUT),
#                 url.getParameter("so.timeout", DEFAULT_SO_TIMEOUT), url.getParameter("max.attempts", DEFAULT_MAX_ATTEMPTS),
#                 url.getPassword(), getConfig())
# ```
# └─ because (1): ```
#    url.getParameter("connection.timeout", DEFAULT_TIMEOUT)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#4):
# ```
# new JedisCluster(nodes, url.getParameter("connection.timeout", DEFAULT_TIMEOUT),
#                 url.getParameter("so.timeout", DEFAULT_SO_TIMEOUT), url.getParameter("max.attempts", DEFAULT_MAX_ATTEMPTS),
#                 url.getPassword(), getConfig())
# ```
# └─ because (1): ```
#    url.getParameter("so.timeout", DEFAULT_SO_TIMEOUT)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Match (RS#4):
# ```
# new JedisCluster(nodes, url.getParameter("connection.timeout", DEFAULT_TIMEOUT),
#                 url.getParameter("so.timeout", DEFAULT_SO_TIMEOUT), url.getParameter("max.attempts", DEFAULT_MAX_ATTEMPTS),
#                 url.getPassword(), getConfig())
# ```
# └─ because (1): ```
#    url.getParameter("max.attempts", DEFAULT_MAX_ATTEMPTS)
#    ```
#  └─ because (2): ```
#     URL url
#     ```
# Over 10 matches. Stopping early.

# %%
from utils.cb.java import *

query = (
  call() % label_as_match()
  |where| any_arg()
    |isa| new() % label('because (1)')
)

results = Evaluator(query).evaluate()
display_results(results)
# Out:
# Match (RS#1):
# ```
# threads.add(thread)
# ```
# └─ because (1): ```
#    thread = new Thread(baseThreadName + "-" + i) {
#            @Override public void run() {
#              try {
#                startGate.await();
#                try {
#                  results.set(index, task.call());
#                } finally {
#                  endGate.countDown();
#                }
#              } catch (Exception e) {
#                throw new RuntimeException(e);
#              }
#            }
#          }
#    ```
# Match (RS#1):
# ```
# threads.add(thread)
# ```
# └─ because (1): ```
#    thread = new Thread(baseThreadName + "-" + i) {
#            @Override public void run() {
#              try {
#                startGate.await();
#                try {
#                  results.set(index, task.call());
#                } finally {
#                  endGate.countDown();
#                }
#              } catch (Exception e) {
#                throw new RuntimeException(e);
#              }
#            }
#          }
#    ```
# Match (RS#1):
# ```
# toList(results)
# ```
# └─ because (1): ```
#    results = new AtomicReferenceArray<T>(nThreads)
#    ```
# Match (RS#1):
# ```
# builder.weigher(custom)
# ```
# └─ because (1): ```
#    custom = new EntryWeigher<Integer, Integer>() {
#          @Override public int weightOf(Integer key, Integer value) {
#            return key + value;
#          }
#        }
#    ```
# Match (RS#1):
# ```
# checkIsEmpty((ConcurrentLinkedHashMap<?, ?>) map, builder)
# ```
# └─ because (1): ```
#    builder = new DescriptionBuilder(description)
#    ```
# Match (RS#1):
# ```
# System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate)
# ```
# └─ because (1): ```
#    stopwatch = new Stopwatch()
#    ```
# Match (RS#1):
# ```
# checkEmpty(deque, builder)
# ```
# └─ because (1): ```
#    builder = new DescriptionBuilder(description)
#    ```
# Match (RS#1):
# ```
# checkIterator(deque, deque.iterator(), builder)
# ```
# └─ because (1): ```
#    builder = new DescriptionBuilder(description)
#    ```
# Match (RS#1):
# ```
# checkIterator(deque, deque.descendingIterator(), builder)
# ```
# └─ because (1): ```
#    builder = new DescriptionBuilder(description)
#    ```
# Match (RS#1):
# ```
# checkCollection(c, builder)
# ```
# └─ because (1): ```
#    builder = new DescriptionBuilder(description)
#    ```
# Match (RS#1):
# ```
# checkSet((Set<? extends E>) c, builder)
# ```
# └─ because (1): ```
#    builder = new DescriptionBuilder(description)
#    ```
# Over 10 matches. Stopping early.
# Match (RS#2):
# ```
# Throwables.getStackTraceAsString(new Exception())
# ```
# └─ because (1): ```
#    new Exception()
#    ```
# Match (RS#2):
# ```
# ConcurrentTestHarness.timeTasks(NUM_THREADS, new Runnable() {
#       @Override public void run() {
#         Long id = Thread.currentThread().getId();
#         map.put(id, id);
#         for (;;) {
#           map.get(id);
#           calls.increment();
#         }
#       }
#     })
# ```
# └─ because (1): ```
#    new Runnable() {
#          @Override public void run() {
#            Long id = Thread.currentThread().getId();
#            map.put(id, id);
#            for (;;) {
#              map.get(id);
#              calls.increment();
#            }
#          }
#        }
#    ```
# Match (RS#2):
# ```
# Executors.newSingleThreadScheduledExecutor().scheduleWithFixedDelay(new Runnable() {
#       final Stopwatch stopwatch = new Stopwatch();
#       @Override public void run() {
#         if (!stopwatch.isRunning()) {
#           System.out.println("Warmup complete");
#           calls = new LongAdder();
#           stopwatch.start();
#           return;
#         }
#         long count = calls.longValue();
#         long rate = count / stopwatch.elapsed(TimeUnit.SECONDS);
#         System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate);
#       }
#     }, WARM_UP_SEC, DISPLAY_DELAY_SEC, TimeUnit.SECONDS)
# ```
# └─ because (1): ```
#    new Runnable() {
#          final Stopwatch stopwatch = new Stopwatch();
#          @Override public void run() {
#            if (!stopwatch.isRunning()) {
#              System.out.println("Warmup complete");
#              calls = new LongAdder();
#              stopwatch.start();
#              return;
#            }
#            long count = calls.longValue();
#            long rate = count / stopwatch.elapsed(TimeUnit.SECONDS);
#            System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate);
#          }
#        }
#    ```
# Match (RS#2):
# ```
# Executors.newSingleThreadScheduledExecutor().scheduleWithFixedDelay(new Runnable() {
#       final Stopwatch stopwatch = new Stopwatch();
#       @Override public void run() {
#         if (!stopwatch.isRunning()) {
#           System.out.println("Warmup complete");
#           calls = new LongAdder();
#           stopwatch.start();
#           return;
#         }
#         long count = calls.longValue();
#         long rate = count / stopwatch.elapsed(TimeUnit.SECONDS);
#         System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate);
#       }
#     }, WARM_UP_SEC, DISPLAY_DELAY_SEC, TimeUnit.SECONDS)
# ```
# └─ because (1): ```
#    new Runnable() {
#          final Stopwatch stopwatch = new Stopwatch();
#          @Override public void run() {
#            if (!stopwatch.isRunning()) {
#              System.out.println("Warmup complete");
#              calls = new LongAdder();
#              stopwatch.start();
#              return;
#            }
#            long count = calls.longValue();
#            long rate = count / stopwatch.elapsed(TimeUnit.SECONDS);
#            System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate);
#          }
#        }
#    ```
# Match (RS#2):
# ```
# Executors.newSingleThreadScheduledExecutor().scheduleWithFixedDelay(new Runnable() {
#       final Stopwatch stopwatch = new Stopwatch();
#       @Override public void run() {
#         if (!stopwatch.isRunning()) {
#           System.out.println("Warmup complete");
#           calls = new LongAdder();
#           stopwatch.start();
#           return;
#         }
#         long count = calls.longValue();
#         long rate = count / stopwatch.elapsed(TimeUnit.SECONDS);
#         System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate);
#       }
#     }, WARM_UP_SEC, DISPLAY_DELAY_SEC, TimeUnit.SECONDS)
# ```
# └─ because (1): ```
#    new Runnable() {
#          final Stopwatch stopwatch = new Stopwatch();
#          @Override public void run() {
#            if (!stopwatch.isRunning()) {
#              System.out.println("Warmup complete");
#              calls = new LongAdder();
#              stopwatch.start();
#              return;
#            }
#            long count = calls.longValue();
#            long rate = count / stopwatch.elapsed(TimeUnit.SECONDS);
#            System.out.printf("%s - %,d [%,d / sec]\n", stopwatch, count, rate);
#          }
#        }
#    ```
# Match (RS#2):
# ```
# doThrow(new AssertionError())
# ```
# └─ because (1): ```
#    new AssertionError()
#    ```
# Match (RS#2):
# ```
# timeTasks(threads, new Runnable() {
#       @Override public void run() {
#         Long id = Thread.currentThread().getId();
#         map.put(id, id);
#         for (;;) {
#           map.get(id);
#           Thread.yield();
#           LockSupport.parkNanos(1L);
#         }
#       }
#     })
# ```
# └─ because (1): ```
#    new Runnable() {
#          @Override public void run() {
#            Long id = Thread.currentThread().getId();
#            map.put(id, id);
#            for (;;) {
#              map.get(id);
#              Thread.yield();
#              LockSupport.parkNanos(1L);
#            }
#          }
#        }
#    ```
# Match (RS#2):
# ```
# createWorkingSet(new ScrambledZipfianGenerator(MASK + 1), MASK + 1)
# ```
# └─ because (1): ```
#    new ScrambledZipfianGenerator(MASK + 1)
#    ```
# Match (RS#2):
# ```
# _values.add(new Pair(weight, value))
# ```
# └─ because (1): ```
#    new Pair(weight, value)
#    ```
# Match (RS#2):
# ```
# cache.put(new Element(key, value))
# ```
# └─ because (1): ```
#    new Element(key, value)
#    ```
# Match (RS#2):
# ```
# cache.putIfAbsent(new Element(key, value), true)
# ```
# └─ because (1): ```
#    new Element(key, value)
#    ```
# Over 10 matches. Stopping early.

# %%
from utils.cb.java import *

# SemGrep: servletresponse-writer-xss
query = (
  call() % label_as_match()
  |where| any_arg_is(
    call(with_name('getParameter')) % label('arg was')
    |where| the_receiver_is(
      param() % label("arg's receiver was")
      |where| the_type()
        |isa| type_(with_name('HttpServletRequest'))
    )
    |and_w| any_arg_is(string())
  )
  |and_w| the_receiver_is(
    call(with_name('getWriter')) % label('receiver was')
    |where| the_receiver()
      |isa| param() % label("receiver's receiver was")
      |where| the_type()
        |isa| type_(with_name('HttpServletResponse'))
  )
)

results = Evaluator(query).evaluate()
display_results(results)
# Out:
# Match (RS#3):
# ```
# writer.println(request.getParameter("function"))
# ```
# └─ arg was: ```
#    request.getParameter("function")
#    ```
#  └─ arg's receiver was: ```
#     HttpServletRequest
#     ```
#   └─ receiver was: ```
#      writer = response.getWriter()
#      ```
#    └─ receiver's receiver was: ```
#       HttpServletResponse
#       ```

# %%
from utils.cb.java import *

# SemGrep: anonymous-ldap-bind
query = (
  new(with_name('InitialDirContext')) % label_as_match()
  |where| the_first_args_receiver_is(
    call(with_name('put'))
    |where| the_first_arg_is(
      field_ref(with_name('SECURITY_AUTHENTICATION'))
    )
    |and_w| the_second_arg_is(
      string() # with_text('none')
    )
  )
)

results = Evaluator(query).evaluate(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ca490b0321b7> in <module>
# ----> 1 from utils.cb.java import *
#       2
#       3 # SemGrep: anonymous-ldap-bind
#       4 query = (
#       5   new(with_name('InitialDirContext')) % label_as_match()
#
# /app/applications/jupyter-extension/nteract_on_jupyter/notebooks/utils/__init__.py in <module>
#      12 import pyarrow.dataset as ds
#      13 import pyarrow.parquet as pq
# ---> 14 import pyarrow.gandiva as gd
#      15
#      16 __F_CACHE = {}
#
# ImportError: libtinfo.so.5: cannot open shared object file: No such file or directory

# %%
# SemGrep: bad-hexa-conversion

digest_results = cb.calls('digest').receiver_is(
    cb.vars(type='MessageDigest').bind()
).bind()

for_over_results = cb.fors().target_container(digest_results).bind()

matches = cb.calls('Integer.toHexString').any_arg_is(
    cb.deep_ref(for_over_results)
)

# %%
# SemGrep: cbc-padding-oracle

matches = cb.calls('getInstance').first_arg_is(
    cb.str(regex=r".*/CBC/PKCS5Padding/")
)

# %%
# SemGrep: command-injection-formatted-runtime-call

# This one is tricky! Trying to say no exec( ... "sh", "-c", user_supplied, ...)

matches1 = cb.calls(['exec', 'loadLibrary']).first_arg_is(
    cb.str_concat_or_format()
).receiver_is(cb.calls('getRuntime').bind())

matches2 = cb.calls('exec').any_arg_is(
    cb.deep_ref(cb.siblings(
        cb.str(regex=r"(sh|bash|ksh|csh|tcsh|zsh)"),
        cb.str('-c'),
        cb.var().has_no_init()
    ))
)

# %%
# SemGrep: formatted-sql-string

# TODO: this one is also quite complex (just long...)
# we can probably make it a lot shorter!

# https://semgrep.dev/editor?registry=java.lang.security.audit.formatted-sql-string.formatted-sql-string

# %%
# SemGrep: http-response-splitting

bad_cookie1 = cb.new('Cookie').any_arg_is(
    cb.calls('getParameter').bind()
)

bad_cookie2 = cb.new('Cookie').any_arg_is(
    cb.method_params().annotated_with('@PathVariable').bind()
)

matches = cb.calls('addCookie').first_arg_is(
    cb.either(bad_cookie1, bad_cookie2)
)

# %%
# SemGrep: ldap-injection

context_var = cb.var([
    'InitialDirContext',
    'DirContext',
    'InitialLdapContext',
    'LdapContext',
    'LdapCtx',
    'EventDirContext'
]).bind()

matches = cb.calls('search').receiver_is(
    context_var
).second_arg_is(
    cb.anything_but(cb.str())
)

# %%
# SemGrep: object-deserialization

matches = cb.new('ObjectInputStream')

# %%
# SemGrep: script-engine-injection

matches = cb.calls('eval').receiver_is(cb.either(
    cb.field(type='ScriptEngine').bind(),
    cb.var(type='ScriptEngine').bind()
)).first_arg_is(
    cb.anything_but(cb.str())
)

# %%
matches1 = merge(
  call() % 'c1'
  |where| the_receiver()
    |isa| formal_parameter_ref() % 'r1',
  
  call() % 'c2'
  |where| the_receiver()
    |isa| ref('r1'),
  
  ref('c1') != ref('c2')
)
